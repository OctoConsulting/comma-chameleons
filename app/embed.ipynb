# %%
import llm_utils

# %%
db = llm_utils.create_vector_db('./Intro_c00.pdf')
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
db.similarity_search("Can you explain what the CMS IOMs refer to and what their purpose is?")
# Out:
# [Document(page_content='CMS MANUAL SYSTEM', metadata={'page': 0, 'source': './Intro_c00.pdf'}),
#  Document(page_content='requirement, or notification. \nThe new online CMS Manual System is orga nized by functional ar ea, (e.g., eligibility, \nentitlement, claims processing, benefit pol icy, program integrity).  The functional \norientation of the new manual eliminates si gnificant redundancy within the manuals and', metadata={'page': 0, 'source': './Intro_c00.pdf'}),
#  Document(page_content='Specifically, the CMS Manual System will include the following functional areas: ', metadata={'page': 0, 'source': './Intro_c00.pdf'}),
#  Document(page_content='move that material into the new CMS Manual System and eliminate the corresponding ', metadata={'page': 0, 'source': './Intro_c00.pdf'})]

# %%
db.get(0)
# Out:
# {'ids': ['a7a17154-8e27-11ee-af21-acde48001122',
#   'ea2ac46c-8e27-11ee-8585-acde48001122',
#   '46d37b08-8e2a-11ee-b5d2-acde48001122',
#   '46d37c84-8e2a-11ee-b5d2-acde48001122',
#   '46d37cc0-8e2a-11ee-b5d2-acde48001122',
#   '46d37ce8-8e2a-11ee-b5d2-acde48001122',
#   '46d37d24-8e2a-11ee-b5d2-acde48001122',
#   '46d37d4c-8e2a-11ee-b5d2-acde48001122',
#   '46d37d74-8e2a-11ee-b5d2-acde48001122',
#   '46d37db0-8e2a-11ee-b5d2-acde48001122',
#   '46d37de2-8e2a-11ee-b5d2-acde48001122',
#   '46d37e0a-8e2a-11ee-b5d2-acde48001122',
#   '46d37e32-8e2a-11ee-b5d2-acde48001122',
#   '46d37e50-8e2a-11ee-b5d2-acde48001122',
#   '46d37e6e-8e2a-11ee-b5d2-acde48001122',
#   '46d37e96-8e2a-11ee-b5d2-acde48001122',
#   '46d37eb4-8e2a-11ee-b5d2-acde48001122',
#   '46d37ed2-8e2a-11ee-b5d2-acde48001122',
#   '46d37efa-8e2a-11ee-b5d2-acde48001122',
#   '46d37f18-8e2a-11ee-b5d2-acde48001122',
#   '46d37f36-8e2a-11ee-b5d2-acde48001122',
#   '46d37f5e-8e2a-11ee-b5d2-acde48001122',
# ...

# %%
db.get(1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/deanchanter/Documents/GitHub/comma-chameleons/app/embed.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/Users/deanchanter/Documents/GitHub/comma-chameleons/app/embed.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> db.get(1)
#
# File ~/Documents/GitHub/comma-chameleons/env/lib/python3.11/site-packages/langchain/vectorstores/chroma.py:517, in Chroma.get(self, ids, where, limit, offset, where_document, include)
#     514 if include is not None:
#     515     kwargs["include"] = include
# --> 517 return self._collection.get(**kwargs)
#
# File ~/Documents/GitHub/comma-chameleons/env/lib/python3.11/site-packages/chromadb/api/models/Collection.py:129, in Collection.get(self, ids, where, limit, offset, where_document, include)
#     125 where = validate_where(where) if where else None
#     126 where_document = (
# ...
